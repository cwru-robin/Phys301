# %% [markdown]
# cell resistance $= 10.0M \Omega \pm 0.5M \Omega$

# %%
import scipy.io as io
import matplotlib.pyplot as plt
import numpy as np
import glob

from matplotlib import pyplot as plt
import matplotlib as mpl
import scipy.optimize as opt
import scipy.interpolate as inter
import math
def sin_model(x,A,phi,omega,b):
    return A* np.sin(omega*x+phi)**2+b
def line_model(x,m,b):
    return m*x+b

c2='red' 
c1='blue' 
n=44
def colorFader(c1,c2,mix=0): #fade (linear interpolate) from color c1 (at mix=0) to c2 (mix=1)
    c1=np.array(mpl.colors.to_rgb(c1))
    c2=np.array(mpl.colors.to_rgb(c2))
    return mpl.colors.to_hex((1-mix)*c1 + mix*c2)
def birefringence(phi,d,lam,theta):
    top= phi*lam
    bottom= 2* np.pi*d*np.sin(theta)**2
    return top/bottom

# %% [markdown]
# $\delta=\frac{2\pi d \Delta n}{\lambda}$
#
# where $ d $ is the thickness of the of the LC
#
# $\Delta n $ is the birefringemce
#
# $\lambda$ is the wavelength = 630 nm?
#
# $\delta$ is the phase
#
# $\Delta n(T)= \frac{\lambda}{2 \pi D} \tan^{-1}(\sqrt{\frac{max}{min}})$

# %%
def deltan(phi,lamda,d):
    return (phi*lamda)/(2*np.pi*d)
birecon= (632.8e-9)/(2*np.pi*5e-6)

# %%
xl,yl=[],[]
filenames=glob.glob('Temp*/*.mat')
for i in filenames:
    xl.append(io.loadmat(i)["Tempture"][0])
    yl.append(io.loadmat(i)["Voltage_O"][0])

xfine= np.linspace(0,max(xl[0]),10000)   

p1,cl1 = opt.curve_fit(line_model, xl[1], yl[1],p0=(1,0))
plt.plot(20*xfine+15,line_model(xfine,*p1))
p1
# Out:
# array([0.99636971, 0.72887993])

# %%
cl1
# Out:
# array([[ 1.01522073e-06, -6.64969572e-07],
#        [-6.64969572e-07,  5.82888975e-07]])

# %%
for i in filenames:
    xl.append(io.loadmat(i)["Tempture"][0])
    yl.append(io.loadmat(i)["Voltage_O"][0])

# %%
xl,yl=[],[]
filenames=["20c100-5000.mat","20-5c100-5000.mat","21c100-5000.mat","21-5c100-5000.mat","22c100-5000.mat","22-5c100-5000.mat","23c100-5000.mat","23-5c100-5000.mat","24c100-5000.mat","24-5c100-5000.mat","25-c100-5000.mat","25-5-c100-5000.mat","26-c100-5000.mat","26-5-c100-5000.mat","27-c100-5000.mat","27-5-c100-5000.mat","28-c100-5000.mat","28-5-c100-5000.mat","29-c100-5000.mat","29-5-c100-5000.mat","30-c100-5000.mat","30-5-c100-5000.mat","31-c100-5000.mat","31-5-c100-5000.mat","32-c100-5000.mat","32-5-c100-5000.mat","33-c100-5000.mat","33-5-c100-5000.mat","34-c100-5000.mat","34-5-c100-5000.mat","35-c100-5000.mat","35-5-c100-5000.mat","36-c100-5000.mat","36-5-c100-5000.mat","37-c100-5000.mat","37-5-c100-5000.mat","38-c100-5000.mat","38-5-c100-5000.mat","39-c100-5000.mat","39-5-c100-5000.mat","40-c100-5000.mat"]
for i in filenames:
    xl.append(io.loadmat("DATA1/"+i)["VP"][0])
    yl.append(io.loadmat("DATA1/"+i)["Voltage_O"][0])

# %%
for x,y in zip(xl,yl):
    plt.plot(x,y,".")

# %%
arange= np.arange(20,40.5,.5)
xfine= np.linspace(min(xl[0]),max(xl[0]),10000)
pl=[]
cl=[]

crange=np.arange(1,len(xl)+1)
for x,y,i in zip(arange,yl,crange):
    p,c = opt.curve_fit(sin_model, xl[0], y,p0=(2,2*np.pi/3,1/8000,1.5))
    pl.append(p)
    cl.append(c)
    plt.plot(xfine,sin_model(xfine,*p),color=colorFader(c1,c2,i/n))

# %%
pl=np.array(pl)
cl=np.array(cl)

# %%
iparrell=[]
iperpendiclur=[]
ratio=[]

xfine= np.linspace(min(xl[0])-800,max(xl[0])+500,10000)
for p in pl:
    iparrell.append(max(sin_model(xfine,*p)))
    iperpendiclur.append(min(sin_model(xfine,*p)))
    ratio.append(max(sin_model(xfine,*p))/min(sin_model(xfine,*p)))    
plt.plot(birecon*np.arctan(np.sqrt(ratio)))

# %%
trange=np.arange(20,40.5,.5)
plt.plot(trange,pl.T[1]- pl.T[1][0],".")

# %%
xl,yl=[],[]
filenames=glob.glob('poc0/*.mat')
def keys(x):
    try:
        return(int(x.split()[0][5:7] ) )
    except: 
        return(int(x.split()[0][5:6])  )  

filenames.sort(key = keys )
for i in filenames:
    xl.append(io.loadmat(i)["HV"][0])
    yl.append(io.loadmat(i)["Voltage_R"][0])
yl=np.round(yl,5)

# %%
eyl=0.003*yl+0.002
eyl
# Out:
# array([[0.00374366, 0.00388439, 0.00403514, ..., 0.00477299, 0.0046037 ,
#         0.00443996],
#        [0.0037796 , 0.00386372, 0.00399995, ..., 0.00480437, 0.0046355 ,
#         0.00447128],
#        [0.00381638, 0.00390053, 0.00403793, ..., 0.00482999, 0.00466256,
#         0.0044972 ],
#        ...,
#        [0.0067232 , 0.00665954, 0.00655373, ..., 0.00996389, 0.00999944,
#         0.01002959],
#        [0.0067289 , 0.00666554, 0.00655796, ..., 0.00998858, 0.01002638,
#         0.01006451],
#        [0.00672416, 0.0066635 , 0.00655175, ..., 0.00999743, 0.01003277,
#         0.01006889]])

# %%
for x,y,e in zip(xl,yl,eyl):
    plt.errorbar(x,y,yerr=e,ls='none')

# %%
arange= np.arange(20,40.5,.5)
xfine= np.linspace(min(xl[0])-800,max(xl[0])+500,10000)
pl=[]
cl=[]
crange=np.arange(1,len(xl)+1)
for y,i in zip(yl,crange):
    p,c = opt.curve_fit(sin_model, xl[0], y,p0=(2,0,1/8000,1.5))
    pl.append(p)
    cl.append(c)
    plt.plot(xfine,sin_model(xfine,*p),color=colorFader(c1,c2,i/n))

# %%
np.diag(cl[0])
# Out:
# array([1.89307953e-05, 3.46855062e-05, 4.75020857e-12, 2.31128046e-05])

# %%
pl=np.array(pl)
cl=np.array(cl)   
tange=21*np.arange(0.01,1.32,0.03)+15
plt.plot(tange,pl.T[1]- pl.T[1][0],".")

# %%
iparrell=[]
iperpendiclur=[]
ratio=[]
xfine= np.linspace(min(xl[0])-800,max(xl[0])+500,10000)
for p in pl:
    iparrell.append(max(sin_model(xfine,*p)))
    iperpendiclur.append(min(sin_model(xfine,*p)))
    ratio.append(max(sin_model(xfine,*p))/min(sin_model(xfine,*p)))    
plt.plot(tange,birecon*np.arctan(np.sqrt(ratio)),'.')

# %%
tange=21*np.arange(0.01,1.32,0.03)+15
tange
# Out:
# array([15.21, 15.84, 16.47, 17.1 , 17.73, 18.36, 18.99, 19.62, 20.25,
#        20.88, 21.51, 22.14, 22.77, 23.4 , 24.03, 24.66, 25.29, 25.92,
#        26.55, 27.18, 27.81, 28.44, 29.07, 29.7 , 30.33, 30.96, 31.59,
#        32.22, 32.85, 33.48, 34.11, 34.74, 35.37, 36.  , 36.63, 37.26,
#        37.89, 38.52, 39.15, 39.78, 40.41, 41.04, 41.67, 42.3 ])

# %%
xl,yl=[],[]
filenames=glob.glob('Poc45/*.mat')
def keys(x):
    try:
        return(int(x.split()[0][6:8] ) )
    except: 
        return(int(x.split()[0][6:7])  )  

filenames.sort(key = keys )
for i in filenames:
    xl.append(io.loadmat(i)["HV"][0])
    yl.append(io.loadmat(i)["Voltage_R"][0])

# %%
for x,y in zip(xl,yl):
    plt.plot(x,y,".")

# %%
xfine= np.linspace(min(xl[0])-5000,max(xl[0]+1000),100000)
pl=[]
cl=[]
crange=np.arange(1,len(xl)+1)
for y,i in zip(yl,crange):
    p,c = opt.curve_fit(sin_model, xl[0], y,p0=(.1,np.pi/2,1/8000,.8),bounds=([-np.inf,-np.inf,-np.inf,0],np.inf),max_nfev=10000000)
    pl.append(p)
    cl.append(c)
    plt.plot(xfine,sin_model(xfine,*p),color=colorFader(c1,c2,i/n))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 6
#       4 crange=np.arange(1,len(xl)+1)
#       5 for y,i in zip(yl,crange):
# ----> 6     p,c = opt.curve_fit(sin_model, xl[0], y,p0=(.1,np.pi/2,1/8000,.8),bounds=([-np.inf,-np.inf,-np.inf,0],np.inf),max_nfev=10000000)
#       7     pl.append(p)
#       8     cl.append(c)
#
# File /usr/local/lib/python3.10/dist-packages/scipy/optimize/_minpack_py.py:845, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, **kwargs)
#     842 if 'max_nfev' not in kwargs:
#     843     kwargs['max_nfev'] = kwargs.pop('maxfev', None)
# --> 845 res = least_squares(func, p0, jac=jac, bounds=bounds, method=method,
#     846                     **kwargs)
#     848 if not res.success:
#     849     raise RuntimeError("Optimal parameters not found: " + res.message)
#
# File /usr/local/lib/python3.10/dist-packages/scipy/optimize/_lsq/least_squares.py:928, in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     924     result = call_minpack(fun_wrapped, x0, jac_wrapped, ftol, xtol, gtol,
#     925                           max_nfev, x_scale, diff_step)
#     927 elif method == 'trf':
# --> 928     result = trf(fun_wrapped, jac_wrapped, x0, f0, J0, lb, ub, ftol, xtol,
#     929                  gtol, max_nfev, x_scale, loss_function, tr_solver,
#     930                  tr_options.copy(), verbose)
#     932 elif method == 'dogbox':
#     933     if tr_solver == 'lsmr' and 'regularize' in tr_options:
#
# File /usr/local/lib/python3.10/dist-packages/scipy/optimize/_lsq/trf.py:123, in trf(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     119     return trf_no_bounds(
#     120         fun, jac, x0, f0, J0, ftol, xtol, gtol, max_nfev, x_scale,
#     121         loss_function, tr_solver, tr_options, verbose)
#     122 else:
# --> 123     return trf_bounds(
#     124         fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale,
#     125         loss_function, tr_solver, tr_options, verbose)
#
# File /usr/local/lib/python3.10/dist-packages/scipy/optimize/_lsq/trf.py:327, in trf_bounds(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     325 while actual_reduction <= 0 and nfev < max_nfev:
#     326     if tr_solver == 'exact':
# --> 327         p_h, alpha, n_iter = solve_lsq_trust_region(
#     328             n, m, uf, s, V, Delta, initial_alpha=alpha)
#     329     elif tr_solver == 'lsmr':
#     330         p_S, _ = solve_trust_region_2d(B_S, g_S, Delta)
#
# File /usr/local/lib/python3.10/dist-packages/scipy/optimize/_lsq/common.py:161, in solve_lsq_trust_region(n, m, uf, s, V, Delta, initial_alpha, rtol, max_iter)
#     158     if np.abs(phi) < rtol * Delta:
#     159         break
# --> 161 p = -V.dot(suf / (s**2 + alpha))
#     163 # Make the norm of p equal to Delta, p is changed only slightly during
#     164 # this. It is done to prevent p lie outside the trust region (which can
#     165 # cause problems later).
#     166 p *= Delta / norm(p)
#
# KeyboardInterrupt:

# %%
iparrell=[]
iperpendiclur=[]
ratio=[]
xfine= np.linspace(min(xl[0])-800,max(xl[0])+500,10000)
for p in pl:
    iparrell.append(max(sin_model(xfine,*p)))
    iperpendiclur.append(min(sin_model(xfine,*p)))  
    ratio.append(max(sin_model(xfine,*p))/min(sin_model(xfine,*p)))    
plt.plot(np.arctan(np.sqrt(ratio)))

# %%
pl=np.array(pl)
cl=np.array(cl)   
tange=21*np.arange(0.01,1.32,0.03)+15
plt.plot(tange,pl.T[1]- pl.T[1][0],".")

# %%
xl,yl=[],[]
filenames=glob.glob('poc134/*.mat')
def keys(x):
    try:
        return(int(x.split()[0][6:8] ) )
    except: 
        return(int(x.split()[0][7:8])  )  

filenames.sort(key = keys )
for i in filenames:
    xl.append(io.loadmat(i)["HV"][0])
    yl.append(io.loadmat(i)["Voltage_R"][0])

# %%
for x,y in zip(xl[:],yl[:]):
    plt.plot(x,y,".")

# %%
xfine= np.linspace(min(xl[0]),max(xl[0]),10000)
pl=[]
cl=[]
crange=np.arange(1,len(xl)+1)
for y,i in zip(yl,crange):
    p,c = opt.curve_fit(sin_model, xl[0], y,p0=(2,5*np.pi/4,1/8000,1.5),maxfev=10000)
    pl.append(p)
    cl.append(c)
    plt.plot(xfine,sin_model(xfine,*p),color=colorFader(c1,c2,i/n))

# %%
pl=np.array(pl)
cl=np.array(cl)   
tange=21*np.arange(0.01,1.32,0.03)+15
plt.plot(tange,pl.T[1],".")

# %%
xl,yl=[],[]
filenames=glob.glob('poc180/*.mat')
def keys(x):
    try:
        return(int(x.split()[0][5:7] ) )
    except: 
        return(int(x.split()[0][7:8])  )  

filenames.sort(key = keys )
for i in filenames:
    xl.append(io.loadmat(i)["HV"][0])
    yl.append(io.loadmat(i)["Voltage_R"][0])

# %%
for x,y in zip(xl[:],yl[:]):
    plt.plot(x,y,".")

# %%
xfine= np.linspace(min(xl[0])-800,max(xl[0])+500,10000)
pl=[]
cl=[]
crange=np.arange(1,len(xl)+1)
for y,i in zip(yl,crange):
    p,c = opt.curve_fit(sin_model, xl[0], y,p0=(2,1*np.pi/4,1/8000,1.5),maxfev=10000)
    pl.append(p)
    cl.append(c)
    plt.plot(xfine,sin_model(xfine,*p),color=colorFader(c1,c2,i/n))

# %%
iparrell=[]
iperpendiclur=[]
ratio=[]
xfine= np.linspace(min(xl[0])-800,max(xl[0])+500,10000)
for p in pl:
    iparrell.append(max(sin_model(xfine,*p)))
    iperpendiclur.append(min(sin_model(xfine,*p)))
    ratio.append(max(sin_model(xfine,*p))/min(sin_model(xfine,*p)))    
plt.plot(np.arctan(np.sqrt(ratio)))

# %%
pl=np.array(pl)
cl=np.array(cl)   
tange=21*np.arange(0.01,1.32,0.03)+15
plt.plot(tange,pl.T[1]- pl.T[1][0],".")

# %%
xl,yl=[],[]
filenames=glob.glob('poc224/*.mat')
def keys(x):
    try:
        return(int(x.split()[0][5:7] ) )
    except: 
        return(int(x.split()[0][7:8])  )  

filenames.sort(key = keys )
for i in filenames:
    xl.append(io.loadmat(i)["HV"][0])
    yl.append(io.loadmat(i)["Voltage_R"][0])

# %%
for x,y in zip(xl[:],yl[:]):
    plt.plot(x,y,".")

# %%
xfine= np.linspace(min(xl[0]),max(xl[0]),10000)
pl=[]
cl=[]
crange=np.arange(1,len(xl)+1)
for y,i in zip(yl,crange):
    p,c = opt.curve_fit(sin_model, xl[0], y,p0=(2,1*np.pi/4,1/8000,1.5),maxfev=10000)
    pl.append(p)
    cl.append(c)
    plt.plot(xfine,sin_model(xfine,*p),color=colorFader(c1,c2,i/n))

# %%
pl=np.array(pl)
cl=np.array(cl)   
tange=21*np.arange(0.01,1.32,0.03)+15
plt.plot(tange[:-3],pl.T[1]- pl.T[1][0],".")

# %%
xl,yl=[],[]
filenames=glob.glob('poc270/*.mat')
def keys(x):
    try:
        return(int(x.split()[0][5:7] ) )
    except: 
        return(int(x.split()[0][7:8])  )  

filenames.sort(key = keys )
for i in filenames:
    xl.append(io.loadmat(i)["HV"][0])
    yl.append(io.loadmat(i)["Voltage_R"][0])

# %%
for x,y in zip(xl[:],yl[:]):
    plt.plot(x,y,".")

# %%
xfine= np.linspace(min(xl[0])-1500,max(xl[0])+500,10000)
pl=[]
cl=[]
crange=np.arange(1,len(xl)+1)
for y,i in zip(yl,crange):
    p,c = opt.curve_fit(sin_model, xl[0], y,p0=(2,1*np.pi/4,1/8000,1.5),maxfev=10000)
    pl.append(p)
    cl.append(c)
    plt.plot(xfine,sin_model(xfine,*p),color=colorFader(c1,c2,i/n))

# %%
pl=np.array(pl)
cl=np.array(cl)   
tange=21*np.arange(0.01,1.32,0.03)+15
plt.plot(tange[:-3],pl.T[1]- pl.T[1][0],".")

# %%
iparrell=[]
iperpendiclur=[]
ratio=[]
xfine= np.linspace(min(xl[0])-800,max(xl[0])+500,10000)
for p in pl:
    iparrell.append(max(sin_model(xfine,*p)))
    iperpendiclur.append(min(sin_model(xfine,*p)))
    ratio.append(max(sin_model(xfine,*p))/min(sin_model(xfine,*p)))    
plt.plot(np.arctan(np.sqrt(ratio)))

# %%
xl,yl=[],[]
filenames=glob.glob('poc314/*.mat')
def keys(x):
    try:
        return(int(x.split()[0][5:7] ) )
    except: 
        return(int(x.split()[0][7:8])  )  

filenames.sort(key = keys )
for i in filenames:
    xl.append(io.loadmat(i)["HV"][0])
    yl.append(io.loadmat(i)["Voltage_R"][0])

# %%
for x,y in zip(xl[:],yl[:]):
    plt.plot(x,y,".")

# %%
xfine= np.linspace(min(xl[0]),max(xl[0]),10000)
pl=[]
cl=[]
crange=np.arange(1,len(xl)+1)
for y,i in zip(yl,crange):
    p,c = opt.curve_fit(sin_model, xl[0], y,p0=(2,4*np.pi/7,1/8000,1),maxfev=10000)
    pl.append(p)
    cl.append(c)
    plt.plot(xfine,sin_model(xfine,*p),color=colorFader(c1,c2,i/n))

# %%
pl=np.array(pl)
cl=np.array(cl)   
tange=21*np.arange(0.01,1.32,0.03)+15
plt.plot(tange,pl.T[1]- pl.T[1][0],".")

# %%
xl,yl=[],[]
filenames=glob.glob('volt30c/*.mat')

filenames.sort( )
for i in filenames:
    xl.append(io.loadmat(i)["HV"][0])
    yl.append(io.loadmat(i)["Voltage_R"][0])

# %%
for x,y in zip(xl[:],yl[:]):
    plt.plot(x,y,".")
